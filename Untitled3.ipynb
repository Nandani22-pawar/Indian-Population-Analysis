# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("/content/Indian_Population_1950-to-2023.csv")

# %%
df.head(10)
# Out:
#          date   Population   Annual Growth Rate  \
# 0  12/31/1950    357021100                 2.21
# 1  12/31/1951    364922360                 2.21
# 2  12/31/1952    372997188                 2.21
# 3  12/31/1953    381227705                 2.21
# 4  12/31/1954    389731406                 2.23
# 5  12/31/1955    398577992                 2.27
# 6  12/31/1956    407656597                 2.28
# 7  12/31/1957    416935399                 2.28
# 8  12/31/1958    426295763                 2.25
# 9  12/31/1959    435900352                 2.25
#
#     Life Expectancy from Birth (Years)   Births per 1000 People  \
# 0                               35.210                   44.175
# 1                               35.800                   43.970
# 2                               36.390                   43.764
# 3                               36.980                   43.558
# 4                               37.570                   43.352
# ...

# %%
df.shape
# Out:
# (74, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 8 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   date                                 74 non-null     object
#  1    Population                          74 non-null     int64
#  2    Annual Growth Rate                  74 non-null     float64
#  3    Life Expectancy from Birth (Years)  74 non-null     float64
#  4    Births per 1000 People              74 non-null     float64
#  5    Deaths per 1000 People              74 non-null     float64
#  6    Deaths per 1000 Live Births         74 non-null     float64
#  7    Births per Woman                    74 non-null     float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 4.8+ KB

# %% [markdown]
# DATA CLEANING

# %%
df.isnull().sum()
# Out:
# date                                   0
#  Population                            0
#  Annual Growth Rate                    0
#  Life Expectancy from Birth (Years)    0
#  Births per 1000 People                0
#  Deaths per 1000 People                0
#  Deaths per 1000 Live Births           0
#  Births per Woman                      0
# dtype: int64

# %%
print("Columns in dataset:")
print(df.columns)
# Out:
# Columns in dataset:
# Index(['date', ' Population', ' Annual Growth Rate',
#        ' Life Expectancy from Birth (Years)', ' Births per 1000 People',
#        ' Deaths per 1000 People', ' Deaths per 1000 Live Births',
#        ' Births per Woman'],
#       dtype='object')

# %% [markdown]
# What is the maximum and minimum Population?

# %%
max_population = df[' Population'].max()
min_population = df[' Population'].min()
print("Maximum Population:", max_population)
print("Minimum Population:", min_population)
# Out:
# Maximum Population: 1428627663
# Minimum Population: 357021100

# %% [markdown]
# Draw a histogram of Population.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df[' Population'], kde=True, bins=10)
plt.title('Distribution of Population')
plt.xlabel('Population')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# Create a heatmap of the correlation matrix.

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %% [markdown]
# Is there a relationship between Population and Life Expectancy?

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df[' Population'], y=df[' Life Expectancy from Birth (Years)'], hue=df['date'], palette='viridis')
plt.title('Population vs. Life Expectancy from Birth (Years)')
plt.xlabel('Population')
plt.ylabel('Life Expectancy from Birth (Years)')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(title='Date', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1340/128522711.py:8: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
